# %% [markdown]
# # Python Practice Worksheet: Lists, Tuples, Sets, Strings, and Dictionaries
#
# This worksheet is designed for absolute beginners who learn best by solving small problems. Each question gives you a chance to practice Python by working with real data, experimenting with code, and noticing patterns.
#
# The questions begin very gently and then become more interesting by combining multiple topics such as strings with lists, sets with dictionaries, and tuples with data collection.

# %% [markdown]
# ## Instructions for Students
#
# - Read one question at a time.
# - Try solving it yourself before looking for help.
# - Print values often to understand what your code is doing.
# - If your first idea does not work, change it and test again.
# - Use small experiments in the code cell to understand lists, strings, sets, tuples, and dictionaries.
# - There can be more than one correct solution.
#
# Tip: For each problem, start with the given example data and then try your own examples after your code works.

# %% [markdown]
# ## Question 1: Split a Sentence into a List
#
# Create a variable called `text` with the value:
#
# ```python
# "apple banana mango"
# ```
#
# Convert the string into a list of words and print the list.
#
# Example output:
#
# ```python
# ['apple', 'banana', 'mango']
# ```
#
# Hint: Strings have a method that can break text into pieces.

# %% [markdown]
# ## Question 2: Remove Duplicate Fruits
#
# You are given this list:
#
# ```python
# fruits = ['apple', 'banana', 'apple', 'orange', 'banana']
# ```
#
# Create a set from the list to remove duplicates, then print the set.
#
# After that, convert the set back into a list and print that too.
#
# Hint: A set stores only unique values.

# %% [markdown]
# ## Question 3: Store Name and Age as a Tuple
#
# Create a tuple that stores a student's name and age.
#
# Example:
#
# ```python
# ('Riya', 14)
# ```
#
# Print the full tuple. Then print only the name and only the age using indexing.
#
# Hint: Tuple values can be accessed by position, just like lists.

# %% [markdown]
# ## Question 4: Build a Dictionary from Two Lists
#
# You are given:
#
# ```python
# keys = ['name', 'age', 'city']
# values = ['Aman', 15, 'Delhi']
# ```
#
# Create a dictionary using these two lists and print it.
#
# Expected output:
#
# ```python
# {'name': 'Aman', 'age': 15, 'city': 'Delhi'}
# ```
#
# Hint: Think about pairing one item from the first list with one item from the second list.

# %% [markdown]
# ## Question 5: Count Each Letter in a Word
#
# Take the string:
#
# ```python
# word = 'banana'
# ```
#
# Create a dictionary that counts how many times each letter appears.
#
# Example output:
#
# ```python
# {'b': 1, 'a': 3, 'n': 2}
# ```
#
# Hint: Loop through the string one character at a time.

# %% [markdown]
# ## Question 6: Common Letters Between Two Words
#
# Use these two strings:
#
# ```python
# word1 = 'teacher'
# word2 = 'cheater'
# ```
#
# Find the letters that appear in both words by using sets.
#
# Print the common letters.
#
# Hint: Convert each string into a set first.

# %% [markdown]
# ## Question 7: Create a Word Length Dictionary
#
# You are given:
#
# ```python
# words = ['pen', 'notebook', 'bag', 'scale']
# ```
#
# Create a dictionary where each word is the key and its length is the value.
#
# Example output:
#
# ```python
# {'pen': 3, 'notebook': 8, 'bag': 3, 'scale': 5}
# ```
#
# Hint: Use a loop and `len()`.

# %% [markdown]
# ## Question 8: Extract Unique Words from a Sentence
#
# Use the sentence:
#
# ```python
# sentence = 'red blue red green blue yellow'
# ```
#
# Split the sentence into a list of words. Then create a set of unique words.
#
# Print both the list and the set.
#
# Hint: First solve the list part, then the set part.

# %% [markdown]
# ## Question 9: Convert Word Pairs into a Dictionary
#
# You are given a list of tuples:
#
# ```python
# pairs = [('apple', 3), ('banana', 5), ('mango', 2)]
# ```
#
# Convert this list of tuples into a dictionary and print it.
#
# Then print the value for the key `'banana'`.
#
# Hint: Each tuple already has a key and a value.

# %% [markdown]
# ## Question 10: Count Word Frequency in a Sentence
#
# Use this sentence:
#
# ```python
# text = 'cat dog cat bird dog cat'
# ```
#
# Create a dictionary that counts how many times each word appears.
#
# Example output:
#
# ```python
# {'cat': 3, 'dog': 2, 'bird': 1}
# ```
#
# Hint: Split the string into words before counting.

# %% [markdown]
# ## Question 11: Group Items by First Letter
#
# You are given:
#
# ```python
# items = ['apple', 'ant', 'ball', 'banana', 'cat']
# ```
#
# Create a dictionary where:
# - each key is the first letter
# - each value is a list of words starting with that letter
#
# Example output:
#
# ```python
# {'a': ['apple', 'ant'], 'b': ['ball', 'banana'], 'c': ['cat']}
# ```
#
# Hint: Check whether the first letter is already in the dictionary.

# %% [markdown]
# ## Question 12: Student Marks Summary
#
# Create a dictionary for a student like this:
#
# ```python
# student = {
#     'name': 'Kiran',
#     'marks': [78, 85, 90]
# }
# ```
#
# Print:
# - the student's name
# - the list of marks
# - the highest mark
# - the lowest mark
# - the total of all marks
#
# Hint: This question combines dictionaries and lists.

# %% [markdown]
# ## Question 13: Find Repeated Characters Only
#
# Use the string:
#
# ```python
# text = 'programming'
# ```
#
# Create a set of characters that appear more than once.
#
# Example output could look like:
#
# ```python
# {'r', 'g', 'm'}
# ```
#
# Hint: First count characters using a dictionary, then build a set from the repeated ones.

# %% [markdown]
# ## Question 14: Store Product Data as Nested Structures
#
# Create a dictionary for a shop where each product name is a key and the value is a tuple containing `(price, quantity)`.
#
# Example:
#
# ```python
# products = {
#     'pen': (10, 5),
#     'book': (40, 2),
#     'eraser': (5, 10)
# }
# ```
#
# Print the price and quantity of `'book'`.
# Then print the total value of all `'pen'` items (`price * quantity`).
#
# Hint: This combines dictionaries with tuples.

# %% [markdown]
# ## Question 15: Mini Pattern and Data Challenge
#
# You are given this string of names:
#
# ```python
# data = 'Asha,Ravi,Asha,Neha,Ravi,Ravi'
# ```
#
# Do all of the following:
# - split the string into a list of names
# - create a set of unique names
# - create a dictionary that counts how many times each name appears
# - create a list of tuples like `('Asha', 2)` from the dictionary
#
# Example final dictionary:
#
# ```python
# {'Asha': 2, 'Ravi': 3, 'Neha': 1}
# ```
#
# Hint: Solve it step by step. Print each result before moving to the next one.
