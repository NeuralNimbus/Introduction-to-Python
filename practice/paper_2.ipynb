# %% [markdown]
# # Python Practice Worksheet 2: Mixed Data Challenges
#
# This worksheet is the next step after the first practice set. The questions are still beginner-friendly, but they ask you to think more carefully, combine more than one data type, and solve problems in small steps.
#
# You will work with lists, tuples, sets, strings, and dictionaries, often in the same question.

# %% [markdown]
# ## Instructions for Students
#
# - Read the full question before writing code.
# - Break each problem into smaller steps.
# - Print intermediate results to check your thinking.
# - If a question feels difficult, solve only one part first.
# - Try changing the example data after your code works.
#
# Tip: These questions are designed for experimentation. Use extra lines in the code cells if you want to test ideas.

# %% [markdown]
# ## Question 1: Clean and Count Fruit Names
#
# You are given this string:
#
# ```python
# text = 'apple, banana, apple, mango, banana, apple'
# ```
#
# Do all of the following:
# - split the string into a list of fruit names
# - remove extra spaces from each fruit name
# - create a dictionary that counts how many times each fruit appears
#
# Example final output:
#
# ```python
# {'apple': 3, 'banana': 2, 'mango': 1}
# ```
#
# Hint: First split by comma, then clean each word.

# %% [markdown]
# ## Question 2: Names Longer Than 4 Letters
#
# Use this list:
#
# ```python
# names = ['Asha', 'Ritika', 'Raj', 'Karan', 'Om', 'Neha']
# ```
#
# Create:
# - a new list containing only names longer than 4 letters
# - a set of the first letters of those long names
#
# Print both results.
#
# Hint: Solve the filtering part first.

# %% [markdown]
# ## Question 3: Dictionary of Even and Odd Numbers
#
# You are given:
#
# ```python
# numbers = [3, 8, 11, 14, 17, 20, 25]
# ```
#
# Create a dictionary like this:
#
# ```python
# {'even': [...], 'odd': [...]}
# ```
#
# Put each number into the correct list.
#
# Hint: Check each number one by one.

# %% [markdown]
# ## Question 4: Create a Price Table from Tuples
#
# You are given a list of tuples:
#
# ```python
# items = [('pen', 10), ('book', 40), ('pencil', 5), ('eraser', 5)]
# ```
#
# Convert it into a dictionary.
# Then print the names of all items whose price is less than 10.
#
# Expected dictionary:
#
# ```python
# {'pen': 10, 'book': 40, 'pencil': 5, 'eraser': 5}
# ```
#
# Hint: Make the dictionary first, then loop through it.

# %% [markdown]
# ## Question 5: Find Words That Appear in Both Sentences
#
# Use these two strings:
#
# ```python
# s1 = 'python is fun and useful'
# s2 = 'python is easy and powerful'
# ```
#
# Split both sentences into word lists.
# Then find the words that appear in both sentences.
#
# Print the common words as a set.
#
# Hint: Convert the lists into sets before comparing them.

# %% [markdown]
# ## Question 6: Character Positions in a Word
#
# Take the word:
#
# ```python
# word = 'banana'
# ```
#
# Create a dictionary where each letter is a key and the value is a list of positions where that letter appears.
#
# Example output:
#
# ```python
# {'b': [0], 'a': [1, 3, 5], 'n': [2, 4]}
# ```
#
# Hint: Use the index while looping through the string.

# %% [markdown]
# ## Question 7: Marks by Grade Group
#
# You are given this dictionary:
#
# ```python
# marks = {'Asha': 91, 'Ravi': 73, 'Neha': 88, 'Kiran': 67, 'Mohan': 91}
# ```
#
# Create a new dictionary with these keys:
# - `'90_and_above'`
# - `'below_90'`
#
# The value for each key should be a list of student names in that group.
#
# Hint: Loop through name-mark pairs.

# %% [markdown]
# ## Question 8: Remove Repeated Words but Keep Order
#
# Use this list:
#
# ```python
# words = ['red', 'blue', 'red', 'green', 'blue', 'yellow', 'green']
# ```
#
# Create a new list that keeps only the first time each word appears.
#
# Example output:
#
# ```python
# ['red', 'blue', 'green', 'yellow']
# ```
#
# Hint: A set can help you remember what you have already seen.

# %% [markdown]
# ## Question 9: Build a Simple Contact Book
#
# Create a dictionary from this list of tuples:
#
# ```python
# contacts = [('Asha', '9876'), ('Ravi', '9123'), ('Neha', '9456')]
# ```
#
# Then do all of the following:
# - print the full dictionary
# - print Ravi's phone number
# - add a new contact for `'Karan'`
# - print all contact names as a list
#
# Hint: Convert first, then update.

# %% [markdown]
# ## Question 10: Frequency Table of Word Lengths
#
# Use this list:
#
# ```python
# words = ['pen', 'bag', 'notebook', 'book', 'scale', 'ink']
# ```
#
# Create a dictionary where:
# - each key is a word length
# - each value is the number of words with that length
#
# Example output:
#
# ```python
# {3: 3, 4: 1, 5: 1, 8: 1}
# ```
#
# Hint: Find the length of each word, then count it.

# %% [markdown]
# ## Question 11: Student Data Cleanup
#
# You are given this dictionary:
#
# ```python
# student = {
#     'name': 'Riya',
#     'skills': ['python', 'python', 'typing', 'reading'],
#     'city': 'Pune'
# }
# ```
#
# Do all of the following:
# - print the student's name and city
# - remove duplicate skills
# - print the unique skills as a set
# - print the number of unique skills
#
# Hint: This combines dictionaries, lists, and sets.

# %% [markdown]
# ## Question 12: Reverse a Dictionary
#
# You are given:
#
# ```python
# data = {'a': 1, 'b': 2, 'c': 1, 'd': 2, 'e': 3}
# ```
#
# Create a new dictionary where:
# - each value from the old dictionary becomes a key
# - each new value is a list of old keys that had that value
#
# Example output:
#
# ```python
# {1: ['a', 'c'], 2: ['b', 'd'], 3: ['e']}
# ```
#
# Hint: This is similar to grouping items into buckets.

# %% [markdown]
# ## Question 13: Common and Different Characters
#
# Use these strings:
#
# ```python
# a = 'triangle'
# b = 'integral'
# ```
#
# Create and print:
# - a set of characters common to both strings
# - a set of characters that are only in `a`
# - a set of characters that are only in `b`
#
# Hint: Convert the strings into sets and compare them.

# %% [markdown]
# ## Question 14: Sales Summary from Nested Data
#
# You are given this dictionary:
#
# ```python
# sales = {
#     'Monday': [('pen', 2), ('book', 1)],
#     'Tuesday': [('pen', 3), ('eraser', 4)],
#     'Wednesday': [('book', 2), ('pen', 1)]
# }
# ```
#
# Create a new dictionary that shows the total quantity sold for each product across all days.
#
# Example output:
#
# ```python
# {'pen': 6, 'book': 3, 'eraser': 4}
# ```
#
# Hint: Loop through each day, then each tuple inside that day.

# %% [markdown]
# ## Question 15: Mini Report Card Challenge
#
# You are given this list of tuples:
#
# ```python
# records = [
#     ('Asha', 'Math', 80),
#     ('Asha', 'Science', 85),
#     ('Ravi', 'Math', 75),
#     ('Ravi', 'Science', 82),
#     ('Neha', 'Math', 91)
# ]
# ```
#
# Create a dictionary where each student name is a key and the value is another dictionary of subjects and marks.
#
# Expected structure:
#
# ```python
# {
#     'Asha': {'Math': 80, 'Science': 85},
#     'Ravi': {'Math': 75, 'Science': 82},
#     'Neha': {'Math': 91}
# }
# ```
#
# After that, print:
# - the full dictionary
# - Asha's Science marks
# - the list of all student names
#
# Hint: If a student is not already in the dictionary, create an empty dictionary for that student first.
