# %% [markdown]
# # Python Practice Worksheet 3: Data, Classes, and Exception Handling
#
# This worksheet is the next step after Paper 1 and Paper 2. The problems are a little more challenging, but they are still designed for a beginner who learns by solving problems.
#
# You will continue using lists, tuples, sets, strings, and dictionaries. You will also start practicing two new ideas:
# - classes, to group related data and behavior
# - exception handling, to prevent your program from crashing when input is wrong

# %% [markdown]
# ## Instructions for Students
#
# - Read the whole question before starting.
# - Solve one small part at a time.
# - Use `print()` often to check what is happening.
# - If you see an error, read it carefully and fix one thing at a time.
# - For class questions, first create the class, then make objects, then test them.
# - For exception handling questions, try both correct and incorrect inputs.
#
# Tip: It is completely normal if your first solution does not work. Keep experimenting.

# %% [markdown]
# ## Question 1: Safe Number Conversion
#
# You are given this list of strings:
#
# ```python
# values = ['10', '25', 'hello', '40', '5x']
# ```
#
# Loop through the list and try to convert each item into an integer.
#
# If conversion works, add the number to a new list called `numbers`.
# If conversion fails, print a message like:
#
# ```python
# Could not convert: hello
# ```
#
# Finally print the `numbers` list.
#
# Hint: Use `try` and `except ValueError`.

# %% [markdown]
# ## Question 2: Count Clean Words in a Sentence
#
# Use this string:
#
# ```python
# text = 'pen, book, pen, pencil, book, eraser'
# ```
#
# Do all of the following:
# - split the string into items using commas
# - remove extra spaces from each item
# - create a dictionary that counts each word
# - print the set of unique words
#
# Hint: First make a clean list, then count it.

# %% [markdown]
# ## Question 3: Safe Dictionary Lookup
#
# You are given this dictionary:
#
# ```python
# marks = {'Asha': 85, 'Ravi': 90, 'Neha': 78}
# ```
#
# Try to print the marks for these names:
#
# ```python
# ['Asha', 'Mohan', 'Neha']
# ```
#
# If a name is not found, print a message like:
#
# ```python
# No marks found for Mohan
# ```
#
# Hint: Use `try` and `except KeyError`.

# %% [markdown]
# ## Question 4: Make a Simple `Book` Class
#
# Create a class called `Book`.
#
# Each object should store:
# - `title`
# - `author`
# - `price`
#
# Then create one book object and print all its values.
#
# Example object data:
#
# ```python
# title = 'Python Basics'
# author = 'Riya'
# price = 250
# ```
#
# Hint: Use `__init__` to store the values.

# %% [markdown]
# ## Question 5: Add a Method to a Class
#
# Using the `Book` class from the previous question, add a method called `show_info()`.
#
# When called, it should print a sentence like:
#
# ```python
# Python Basics by Riya costs 250
# ```
#
# Create two book objects and call the method for both.
#
# Hint: Methods are functions inside a class.

# %% [markdown]
# ## Question 6: Store Objects in a List
#
# Create a class called `Student` with:
# - `name`
# - `marks`
#
# Make three student objects and store them in a list.
# Then loop through the list and print each student's name and marks.
#
# Hint: A list can store objects just like it stores strings or numbers.

# %% [markdown]
# ## Question 7: Average Marks with Exception Handling
#
# Write code that asks the user to enter three marks.
#
# Convert them into integers and print the average.
# If the user enters something that is not a number, print a friendly message instead of crashing.
#
# Example message:
#
# ```python
# Please enter numbers only.
# ```
#
# Hint: Put the conversion inside `try`.

# %% [markdown]
# ## Question 8: Group Words by Length
#
# Use this list:
#
# ```python
# words = ['pen', 'book', 'notebook', 'bag', 'scale', 'ink']
# ```
#
# Create a dictionary where:
# - each key is a word length
# - each value is a list of words of that length
#
# Example output:
#
# ```python
# {3: ['pen', 'bag', 'ink'], 4: ['book'], 5: ['scale'], 8: ['notebook']}
# ```
#
# Hint: This is like making groups.

# %% [markdown]
# ## Question 9: Simple Bank Account Class
#
# Create a class called `BankAccount` with:
# - `name`
# - `balance`
#
# Add a method called `deposit(amount)` that increases the balance.
# Create one object, deposit money twice, and print the final balance.
#
# Hint: Update the object's balance inside the method.

# %% [markdown]
# ## Question 10: Safe Withdrawal
#
# Add a method called `withdraw(amount)` to the `BankAccount` class.
#
# Rules:
# - if `amount` is greater than the balance, raise a `ValueError`
# - otherwise subtract the amount from the balance
#
# Call the method inside a `try` block.
# If withdrawal is not possible, print a friendly message.
#
# Hint: You can use `raise ValueError('message')`.

# %% [markdown]
# ## Question 11: Build a Dictionary from Student Objects
#
# Using the `Student` class, create three student objects.
#
# Now build a dictionary where:
# - the key is the student name
# - the value is the student's marks
#
# Then print:
# - the full dictionary
# - the highest mark
# - the name of the student who has that highest mark
#
# Hint: First create the dictionary, then solve the other parts.

# %% [markdown]
# ## Question 12: Class with a List Attribute
#
# Create a class called `ShoppingCart`.
#
# It should have:
# - `customer_name`
# - `items` which starts as an empty list
#
# Add a method `add_item(item)` that adds an item to the list.
# Create one cart object and add at least four items, including one repeated item.
#
# Then print:
# - the full list of items
# - a set of unique items
# - a dictionary counting how many times each item appears
#
# Hint: This question mixes classes with old topics.

# %% [markdown]
# ## Question 13: Safe Division for Marks
#
# Write code that asks the user for:
# - total marks
# - number of subjects
#
# Then calculate the average marks.
#
# Handle these two problems safely:
# - the user enters text instead of a number
# - the user enters `0` for number of subjects
#
# Print different friendly messages for both cases.
#
# Hint: You may need more than one `except` block.

# %% [markdown]
# ## Question 14: Library Class with Nested Data
#
# Create a class called `Library`.
#
# It should have:
# - `name`
# - `books`, which is a dictionary
#
# Add a method `add_book(title, author)` that stores books like this:
#
# ```python
# {'Python Basics': 'Riya', 'Math Tricks': 'Aman'}
# ```
#
# Create one library object, add at least three books, and print:
# - the full book dictionary
# - the set of all authors
# - the list of all titles
#
# Hint: The object will contain a dictionary, and the dictionary will contain strings.

# %% [markdown]
# ## Question 15: Mini Result Manager
#
# Create a class called `ResultManager`.
#
# It should store student records in a dictionary like this:
#
# ```python
# {
#     'Asha': [80, 90, 85],
#     'Ravi': [70, 88, 75]
# }
# ```
#
# Add these methods:
# - `add_student(name, marks_list)`
# - `show_average(name)` which prints the average of that student's marks
#
# Now do all of the following:
# - create one `ResultManager` object
# - add at least three students
# - show the average for one student
# - safely handle the case where a name is not found
#
# Hint: Use a class, a dictionary, a list, and exception handling together.
